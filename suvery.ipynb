# %%
#@title Survey and Feedback Form for Jonathan's Final Project
#@markdown ## Introduction
#@markdown Thank you for taking the time to listen to the generated music clips and provide feedback! 
#@markdown Click the Run All button at the top, listen to the clips, and fill out the form at the end. 
try: 
    import google.colab  # noqa: F401
    import gdown
    in_colab = True
except ImportError:
    pass
    in_colab = False

from IPython.display import Audio, display
if in_colab:
    import subprocess
    import os
    if not os.path.isdir('survey_samples'):
        # Google Drive share link
        google_drive_link = 'https://drive.google.com/file/d/17d38LD0q_C0zX6_gyIV9JK_V3urNaAzY/view?usp=share_link'

        # Extract the file ID from the link
        file_id = google_drive_link.split('/')[-2]
        output_filename = 'survey_samples.zip'

        gdown.download(google_drive_link, output_filename, quiet=False, fuzzy=True)

        subprocess.run(
              ["unzip", "-q", "-o", output_filename, "-d", 'survey_samples'],
              check=True
          )
# @markdown ## Feedback and Survey Form
# @markdown #### <b>Please complete!</b>
# @markdown Please fill out the google form if you don't mind so that I can gather evaluation data.
# @markdown <p>It should only take a few minutes and will help me a lot in improving the model and the notebook experience. Thanks in advance!</p>
# @markdown <h2><font size=5 color=blue>Listen and Classify Genre</font></h2>
# @markdown <p>Listen to the generated clips and classify the genre in the Google Form.</p>
print("Clip #1")
display(Audio('./survey_samples/1_074986.wav'))
print("Clip #2")
display(Audio('./survey_samples/2_11747.wav'))
print("Clip #3")
display(Audio('./survey_samples/3_263060.wav'))
print("Clip #4")
display(Audio('./survey_samples/4_191673.wav'))
print("Clip #5")
display(Audio('./survey_samples/5_14647.wav'))
print("Clip #6")
display(Audio('./survey_samples/6_066680.wav'))
print("Clip #7")
display(Audio('./survey_samples/7_393892.wav'))
print("Clip #8")
display(Audio('./survey_samples/8_151793.wav'))
print("Cllip #9")
display(Audio('./survey_samples/9_12781.wav'))

FORM_URL = "https://docs.google.com/forms/d/e/1FAIpQLSfnu5JGQv4WunY-2o0htNv2nVT74rNImMMG-AmXS-2NvOmNtw/viewform?usp=dialog"

if FORM_URL:
    display(IFrame(src=FORM_URL, width='100%', height='600px'))
else:
    print("Please provide a Google Form URL in the input field above.")
